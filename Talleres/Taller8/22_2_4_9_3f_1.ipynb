# %% [markdown]
# Pobabilidad condicional y total

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
##2

u1 = ["r","r","r","n","v","v","v","v","v","v"]
#u1= [3,1,6]
u2 = ["r","r","r","r","r","r","n","n","v","v"]
#u2= [6,2,2]

#a:
def probabilidad_roja():
  dado = np.random.randint(1,7)
  if dado == 1 or 2:
    roja = np.random.choice(r,p=u1)
  else:
    roja = np.random.choice(r,p=u2)

  p = roja/10
  return p

#b:
def probabilidad_negra():
  dado = np.random.randint(1,7)
  if dado == 1 or 2:
    negra = np.random.choice(n,p=u1)
  else:
    negra = np.random.choice(n,p=u2)

  n = negra/10
  return p

#c:
def probabilidad_negra_u1():
  dado = np.random.randint(1,7)
  if dado == 1 or 2:
    negra= np.random.choice(r,p=u1)
  else:
    negra= 0

  p = negra/5
  return p

#d:
def probabilidad_negra_u2():
  dado = np.random.randint(1,7)
  if dado == 1 or 2:
    negra= 0
  else:
    negra= np.random.choice(r,p=u2)

  p = negra/5
  return p

# %% [markdown]
# Axiomas de la probabilidad

# %%
## 1

#P es medida de probabilidad: Axiomas de Kolmogórov

def medida_prob():
  v= "si cumple"
  P = a1*p1 + a2*p2
  C = a1+a2 -1
  n= len(P)
  if n==1:
    return v

## 3f

# %% [markdown]
# ![WhatsApp Image 2022-11-11 at 4.08.31 PM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# Tecnicas de conteo

# %%
## 22 : Cuántas sumas de 3 enteros no negativos dan 10

#Los numeros deben ser menores o iguales a 10 y se pueden repetir (combinacion)

n= 3
r= 10
solucion = (np.math.factorial(n+r-1))/ (np.math.factorial(r)*np.math.factorial(n-1))
print(solucion)
# Out:
# 66.0

# %% [markdown]
# Generales de probabilidad

# %%
from os import getrandom
## 4

#La formula para calcular las fechas diferentes de cumpleaños: 365/365 * 364/365 * 363/365 * .... 1/365

#a
n= []
for i in range(1,365):
  n= i/365
  i+=1

prob= np.prod(n) *100
print(prob)
#b
gra=[]
for i in range(1,80):
  gra= i/365
  i+=1

prob2= np.prod(gra)

plt.plot(gra,n)
# Out:
# 99.72602739726028

# %%
## 9

#Utilizando el código de clase como guía
def lanzamiento():
  eventos = 0
  for i in range(0.1,0.9):
    c =p1
    s= 1-p1
    for j in range(0.1,0.5):
      if sample[0][1] ==1:
        c+=1
      if sample[1][1] ==1:
        s+=1
    eventos+=1
